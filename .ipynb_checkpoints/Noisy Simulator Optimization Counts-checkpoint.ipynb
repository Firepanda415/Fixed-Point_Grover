# %%
import matplotlib.pyplot as plt
from matplotlib import cm
plt.rcParams["figure.dpi"] = 150

from qiskit.circuit.library import U3Gate

from qiskit.ignis.verification.tomography import state_tomography_circuits, StateTomographyFitter
from qiskit.quantum_info import DensityMatrix, Statevector
from qiskit.quantum_info import state_fidelity
import qiskit.ignis.mitigation.measurement as mc

from qiskit import IBMQ, transpile,Aer,execute
from qiskit import QuantumCircuit
from qiskit.providers.aer import AerSimulator
from qiskit.tools.visualization import plot_histogram

from qiskit.quantum_info import Kraus, SuperOp, Operator
from qiskit.providers.aer.noise import NoiseModel
from qiskit.providers.aer.noise import QuantumError, ReadoutError
from qiskit.providers.aer.noise import pauli_error
from qiskit.providers.aer.noise import depolarizing_error
from qiskit.providers.aer.noise import thermal_relaxation_error

from scipy.optimize import minimize
from scipy.optimize import Bounds

import nevergrad as ng
from concurrent import futures

from FPG import * # The functions from FP Grover Implementation notebook

import warnings
warnings.filterwarnings('ignore')

import logging
logger = logging.getLogger()
logger.setLevel(logging.CRITICAL)

# %%
# Global variable
# Input parameters for the Fixed-Point Grover's search
n = 2
itr = 4
indices_to_mark = 3
d = np.sqrt(0.1)

shots = 8192

# %%
def counts_to_probs(counts):
    counts_shots = np.sum([v for v in counts.values()])
    probs = np.zeros(2**(n+1), dtype=np.float64)
    for k,v in counts.items():
        probs[int(k,2)] = v/counts_shots
    return probs

def VD(p,q):
    np_p = np.array(p)
    np_q = np.array(q)
    return 0.5*np.abs(np_p - np_q).sum()

def param_FP_Grover_circuit(noise_params, return_params = False):
    # Does not include measurements to allow state tomography
    # noise_params: a numpy array reshaped to num_parameters*num_qubits*n_iters from dimension [num_parameters, num_qubits, num_iters]. 
    #               E.g., before reshape, noise_params[:,0,0] gives noise parameters for the first qubit in the first iteration

    angles = noise_params.reshape((3, n)) #NOT A NUMPY ARRAY FROM SCIPY.OPTIMIZE
    l = itr
    L = 2*l+1

    gamma_inverse = Chbshv_poly(1/L, 1/d)
    omega = 1 - Chbshv_poly(1/L, 1/d)**(-2)

    alpha =  mpm.zeros(1,l)
    beta = mpm.zeros(1,l)
    for i in range(l): # use i instead of j since python use 1j for sqrt(-1)
        alpha[i] = 2*mpm.acot(mpm.tan(2*mpm.pi*(i+1)/L) * mpm.sqrt(1-1/gamma_inverse**2))
        beta[l-(i+1)+1-1] = -alpha[i]

    # Convert to numpy
    gamma_inverse = np.array([gamma_inverse], dtype=complex)[0].real
    omega = np.array([omega], dtype=complex)[0].real
    alpha = np.array(alpha.tolist()[0], dtype=complex).real
    beta = np.array(beta.tolist()[0], dtype=complex).real
    
    r = QuantumRegister(n+1)
    qc = QuantumCircuit(r)
    # Initialize |s>
    for i in range(n):
        qc.h(n-i) # Measurement order is the reversed qubit order
    for i in range(itr):
        # St(beta)
        oracle(qc,n, indices_to_mark) # turn state into |T>|1> + sum_i (|w_i>|0>) where w_i are NOT target state, T is the target state
        qc.p(beta[i],0) # when beta[i] = pi, this is simply a Z gate, so only has phase kickback on |T>|1> but not |w_i>|0>
        oracle(qc,n, indices_to_mark)  # to uncompute the ancillary
        # St(alpha)
        for q in range(n):
            qc.h(n-q)
        qc.barrier()
        for q in range(n-1):
            qc.x(n-q)
        qc.p(-alpha[i]/2, 1)
        qc.mct(list(range(n, 1, -1)), 1)
        qc.mct(list(range(n, 1, -1)), 0)
        qc.p(-alpha[i]/2, 1)
        qc.p(-alpha[i]/2, 0)
        qc.mct(list(range(n, 1, -1)), 1)
        qc.mct(list(range(n, 1, -1)), 0)
        for q in range(n-1):
            qc.x(n-q)
        qc.p(alpha[i], 1)
        qc.barrier()
        for q in range(n):
            qc.h(n-q)
        qc.barrier()
        for q in range(n):
            qc.u(angles[0,n-q-1], angles[1,n-q-1], angles[2,n-q-1], n-q) # Add noise/denoise here
        qc.barrier()
    if return_params:
        return qc, (gamma_inverse, 1/2**n, omega, alpha, beta)
    else:
        return r, qc

# %% [markdown]
# # A Noisy Simulator

# %%
# Load IBMQ Account and choose a real backend
IBMQ.load_account()
provider = IBMQ.get_provider('ibm-q')
name = 'ibmq_belem'
backend = provider.get_backend(name)

 # Record some information
basis_gates = backend.configuration().basis_gates
coupling_map = backend.configuration().coupling_map

# Create a noisy simulator using this backend
fake_backend = AerSimulator.from_backend(backend)

# %%
# Parameters
p_1q = 4e-4 # 1-qubit depolarizing error rate
p_2q = 5e-3 # 2-qubit depolarizing error rate

# Create an empty noise model
noise_model = NoiseModel(basis_gates) # Use the same basis_gates as the selected backend to ensure the circuit depth is the same

# Add depolarizing errors
error_1q = depolarizing_error(p_1q, 1)
error_2q = depolarizing_error(p_2q, 2)
noise_model.add_all_qubit_quantum_error(error_1q, ['id', 'rz', 'sx', 'x'])
noise_model.add_all_qubit_quantum_error(error_2q, ['cx'])

# Add the noise model to a simulator
sim_noise = AerSimulator(noise_model=noise_model)
print(noise_model)
# Out:
# NoiseModel:
#   Basis gates: ['cx', 'id', 'reset', 'rz', 'sx', 'x']
#   Instructions with noise: ['sx', 'rz', 'x', 'id', 'cx']
#   All-qubits errors: ['id', 'rz', 'sx', 'x', 'cx']

# %% [markdown]
# # Try Tomography

# %%
# Global variable true_state
gs_qc = FP_Grover_circuit(n, indices_to_mark, itr, d, return_params = False)
gs_qc.measure_all()
trans_gs_qc = transpile(gs_qc,sim_noise, optimization_level=0)
noisy_result = sim_noise.run(trans_gs_qc, shots=shots, optimization_level=0).result()
noisy_counts = noisy_result.get_counts()
noisy_probs = counts_to_probs(noisy_counts)
noisy_probs
# Out:
# array([0.05505371, 0.03759766, 0.05456543, 0.04211426, 0.05749512,
#        0.03283691, 0.67211914, 0.04821777])

# %%
# The function we want to optimize
# return negative fidelity
# So ideally is -1
def blackbox_fidelity(noise_params):
    # Obtain tomography circuit
    r, param_qc = param_FP_Grover_circuit(noise_params)
    param_state = Statevector.from_instruction(param_qc)
    param_prob = param_state.probabilities()
    return VD(noisy_probs, param_prob)

# %%
blackbox_fidelity(np.zeros((3, n), dtype=np.float64).reshape(3*n))
# Out:
# 0.3173917651594587

# %%
blackbox_fidelity(np.array([1]*3*n, dtype=np.float64).reshape(3*n))
# Out:
# 0.23764424286009295

# %%
# NOT USED initial point
noise_params_x0 = np.zeros((3, n), dtype=np.float64).reshape(3*n)

# Bounds for noise parameters
# NOTE: lb and ub must be np.array, otherwise raise errors (cannot handle the case when index is an array)
lb = np.array([0]*3*n) 
ub = np.array([2*3.141592653589793]*3*n)


optimizer = ng.optimizers.CMA(parametrization=n*3, budget=500*n*itr, num_workers=10)
for i in range(n*3):
    optimizer.parametrization.register_cheap_constraint(lambda x: x[i] >= lb[i])
    optimizer.parametrization.register_cheap_constraint(lambda x: x[i] <= ub[i])

# recommendation = optimizer.minimize(blackbox_fidelity, verbosity=2)
with futures.ThreadPoolExecutor(max_workers=optimizer.num_workers) as executor:
    recommendation = optimizer.minimize(blackbox_fidelity, executor=executor, batch_mode=False, verbosity=1)
# Out:
# Launching 10 jobs with new suggestions
# Updating fitness with value 0.4167815209946695
# Updating fitness with value 0.6471374346184937
# 3990 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.7851314938827351
# 3988 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.21007277733988045
# Updating fitness with value 0.43945642597295487
# Updating fitness with value 0.808874864548049
# Updating fitness with value 0.6483238156528718
# Updating fitness with value 0.37758188710288704
# 3987 remaining budget and 5 running jobs
# Launching 5 jobs with new suggestions
# Updating fitness with value 0.8296631369593956
# Updating fitness with value 0.4103418577043222
# 3982 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.2073743448541027
# Updating fitness with value 0.2111186549766325
# Updating fitness with value 0.7626833208049946
# 3980 remaining budget and 7 running jobs
# Launching 3 jobs with new suggestions
# Updating fitness with value 0.708210669388524
# Updating fitness with value 0.7866644116390211
# 3977 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.7412941876955099
# 3975 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.37661688513748226
# Updating fitness with value 0.7902007905126953
# Updating fitness with value 0.8184358764590745
# Updating fitness with value 0.27557997931908806
# Updating fitness with value 0.6787266603540765
# Updating fitness with value 0.530840557950836
# 3974 remaining budget and 4 running jobs
# Launching 6 jobs with new suggestions
# Updating fitness with value 0.2737793065547477
# Updating fitness with value 0.3491986815710624
# Updating fitness with value 0.5702884523113114
# 3968 remaining budget and 7 running jobs
# Launching 3 jobs with new suggestions
# Updating fitness with value 0.3936940456496585
# 3965 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.2800768879239597
# 3964 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.602729373418544
# Updating fitness with value 0.3831438019105372
# 3963 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.6889487500969936
# Updating fitness with value 0.3540953843859834
# Updating fitness with value 0.5119253069511729
# Updating fitness with value 0.5086442430470195
# 3961 remaining budget and 6 running jobs
# Launching 4 jobs with new suggestions
# Updating fitness with value 0.2788962387498543
# Updating fitness with value 0.7514818673844921
# Updating fitness with value 0.7786816294664045
# 3957 remaining budget and 7 running jobs
# Launching 3 jobs with new suggestions
# Updating fitness with value 0.5141599001873141
# Updating fitness with value 0.278408988147096
# Updating fitness with value 0.6388477189655604
# Updating fitness with value 0.30554505362423784
# 3954 remaining budget and 6 running jobs
# Launching 4 jobs with new suggestions
# Updating fitness with value 0.5171220691057044
# Updating fitness with value 0.26627083623025893
# Updating fitness with value 0.20816567042093825
# Updating fitness with value 0.4488356807937198
# Updating fitness with value 0.4473346289355778
# Updating fitness with value 0.3012527355660584
# 3950 remaining budget and 4 running jobs
# Launching 6 jobs with new suggestions
# Updating fitness with value 0.21717456763155246
# 3944 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.20417165439038715
# Updating fitness with value 0.7512352292272777
# Updating fitness with value 0.22278768268557256
# 3943 remaining budget and 7 running jobs
# Launching 3 jobs with new suggestions
# Updating fitness with value 0.19461846107596323
# Updating fitness with value 0.26024787966277124
# Updating fitness with value 0.2843053244903012
# Updating fitness with value 0.46259135648760885
# Updating fitness with value 0.3069399900449199
# Updating fitness with value 0.48550011787648484
# 3940 remaining budget and 4 running jobs
# Launching 6 jobs with new suggestions
# Updating fitness with value 0.6449292426853434
# 3934 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.5829926167427075
# 3933 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.7342417289060835
# 3932 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.1607666015624986
# Updating fitness with value 0.8848072095655761
# Updating fitness with value 0.7316561870335757
# 3931 remaining budget and 7 running jobs
# Launching 3 jobs with new suggestions
# Updating fitness with value 0.7615437347782323
# Updating fitness with value 0.367905268545021
# Updating fitness with value 0.8382477268330377
# 3928 remaining budget and 7 running jobs
# Launching 3 jobs with new suggestions
# Updating fitness with value 0.5492469345258157
# Updating fitness with value 0.29290256627343914
# 3925 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.2967876206213608
# Updating fitness with value 0.26432638110575
# Updating fitness with value 0.7747212581381072
# 3923 remaining budget and 7 running jobs
# Launching 3 jobs with new suggestions
# Updating fitness with value 0.2659740271350321
# Updating fitness with value 0.43130203864606936
# Updating fitness with value 0.6760933480606383
# 3920 remaining budget and 7 running jobs
# Launching 3 jobs with new suggestions
# Updating fitness with value 0.19210252889053225
# 3917 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.2264342516967034
# 3916 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.6881759624748269
# Updating fitness with value 0.5952172020178919
# 3915 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.4665553216456028
# 3913 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.5784886324955569
# Updating fitness with value 0.29978019560860214
# Updating fitness with value 0.2052443889359632
# 3912 remaining budget and 7 running jobs
# Launching 3 jobs with new suggestions
# Updating fitness with value 0
remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.5713536875532044
# Updating fitness with value 0.2190724773964455
# 3815 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.30608140130990785
# 3813 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.2668948856332241
# 3812 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.20585101366383138
# Updating fitness with value 0.39476449902212996
# 3811 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.17723865329838728
# Updating fitness with value 0.686789333344292
# Updating fitness with value 0.25448112351290847
# Updating fitness with value 0.43612496067622886
# Updating fitness with value 0.47635062070153045
# Updating fitness with value 0.268617041122616
# Updating fitness with value 0.21568927784335754
# 3809 remaining budget and 3 running jobs
# Launching 7 jobs with new suggestions
# Updating fitness with value 0.2190272295379808
# 3802 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.19575342922709485
# 3801 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.40379428150292695
# Updating fitness with value 0.21817562826376236
# Updating fitness with value 0.28062454183051566
# Updating fitness with value 0.6557680578073867
# Updating fitness with value 0.16076660156249828
# 3800 remaining budget and 5 running jobs
# Launching 5 jobs with new suggestions
# Updating fitness with value 0.1607666015624986
# Updating fitness with value 0.2535220227808466
# Updating fitness with value 0.7218325877642886
# 3795 remaining budget and 7 running jobs
# Launching 3 jobs with new suggestions
# Updating fitness with value 0.6130422953591456
# 3792 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.7005123552055514
# 3791 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.47799189622255395
# Updating fitness with value 0.2284251234775385
# Updating fitness with value 0.2275132482379698
# Updating fitness with value 0.21196259971099793
# Updating fitness with value 0.29492405480200073
# Updating fitness with value 0.2512710357159217
# 3790 remaining budget and 4 running jobs
# Launching 6 jobs with new suggestions
# Updating fitness with value 0.17461780370072352
# Updating fitness with value 0.2181458263609483
# 3784 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.6865391275335201
# 3782 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.1972645838036944
# Updating fitness with value 0.3621719616823794
# Updating fitness with value 0.2272858449373152
# Updating fitness with value 0.1785350672859971
# 3781 remaining budget and 6 running jobs
# Launching 4 jobs with new suggestions
# Updating fitness with value 0.3814065763537457
# Updating fitness with value 0.6472045379715324
# Updating fitness with value 0.41171803116421213
# Updating fitness with value 0.24075517258351398
# Updating fitness with value 0.5776046666973711
# Updating fitness with value 0.1718671922867603
# 3777 remaining budget and 4 running jobs
# Launching 6 jobs with new suggestions
# Updating fitness with value 0.25693097442559965
# Updating fitness with value 0.25184145366385247
# 3771 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.23818304027810955
# Updating fitness with value 0.5497251979583393
# Updating fitness with value 0.2567847760347187
# Updating fitness with value 0.30349436843614475
# Updating fitness with value 0.4213821990644723
# Updating fitness with value 0.20509593604169346
# 3769 remaining budget and 4 running jobs
# Launching 6 jobs with new suggestions
# Updating fitness with value 0.2643077718371321
# Updating fitness with value 0.33195831080608507
# 3763 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.27511051364960315
# Updating fitness with value 0.21755282561343714
# 3761 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.37576968282606704
# Updating fitness with value 0.5814922248138088
# Updating fitness with value 0.20816490988209027
# Updating fitness with value 0.19066443472608288
# 3759 remaining budget and 6 running jobs
# Launching 4 jobs with new suggestions
# Updating fitness with value 0.6978274811868709
# Updating fitness with value 0.2258206813873277
# 3755 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.39556389553127747
# Updating fitness with value 0.21900897818995343
# 3753 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.21674169548210273
# Updating fitness with value 0.3400501792455583
# 3751 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.2069574987132104
# Updating fitness with value 0.1607666015624983
# Updating fitness with value 0.1898192917429037
# Updating fitness with value 0.20380732890363892
# Updating fitness with value 0.5482745636109458
# Updating fitness with value 0.1951873308003011
# Updating fitness with value 0.35396109514346463
# Updating fitness with value 0.18263207419773994
# 3749 remaining budget and 2 running jobs
# Launching 8 jobs with new suggestions
# Updating fitness with value 0.2615297322205519
# 3741 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.20171624408967015
# Updating fitness with value 0.3729142717994326
# Updating fitness with value 0.2919642791194994
# Updating fitness with value 0.16076660156249908
# Updating fitness with value 0.16076660156249867
# Updating fitness with value 0.2763001822121357
# 3740 remaining budget and 4 running jobs
# Launching 6 jobs with new suggestions
# Updating fitness with value 0.20213899601271723
# 3734 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.40146530733766816
# 3733 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.2823676266118127
# 3732 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.25784895023364907
# 3731 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.4164281151445287
# Updating fitness with value 0.5005302167712649
# Updating fitness with value 0.32498424726576375
# Updating fitness with value 0.2739999093989121
# 3730 remaining budget and 6 running jobs
# Launching 4 jobs with new suggestions
# Updating fitness with value 0
remaining budget and 7 running jobs
# Launching 3 jobs with new suggestions
# Updating fitness with value 0.16076660156249828
# Updating fitness with value 0.16076660156249817
# 3523 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.19990670031892946
# 3521 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.18083703753651853
# 3520 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.1970048106035927
# Updating fitness with value 0.1666714338495316
# 3519 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.23296621901115858
# 3517 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.176363986822002
# Updating fitness with value 0.18744916235538772
# Updating fitness with value 0.18160878296650912
# Updating fitness with value 0.1607666015624981
# 3516 remaining budget and 6 running jobs
# Launching 4 jobs with new suggestions
# Updating fitness with value 0.1635294478725675
# 3512 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.17325712016631523
# Updating fitness with value 0.16076660156249878
# Updating fitness with value 0.17696910246921377
# 3511 remaining budget and 7 running jobs
# Launching 3 jobs with new suggestions
# Updating fitness with value 0.17631400438428918
# Updating fitness with value 0.21095350474023272
# 3508 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.16076660156249878
# Updating fitness with value 0.173814836252396
# Updating fitness with value 0.1639678965106798
# 3506 remaining budget and 7 running jobs
# Launching 3 jobs with new suggestions
# Updating fitness with value 0.18235720859160331
# Updating fitness with value 0.1725033231939819
# 3503 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.16551822129130453
# Updating fitness with value 0.17154184011652018
# 3501 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.1945846629821016
# Updating fitness with value 0.16076660156249856
# Updating fitness with value 0.21807672230591874
# 3499 remaining budget and 7 running jobs
# Launching 3 jobs with new suggestions
# Updating fitness with value 0.16076660156249922
# Updating fitness with value 0.16087286463940675
# Updating fitness with value 0.20524748555435135
# 3496 remaining budget and 7 running jobs
# Launching 3 jobs with new suggestions
# Updating fitness with value 0.1607666015624988
# 3493 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.18027323268107687
# 3492 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.19116022751823591
# 3491 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.16076660156249928
# Updating fitness with value 0.1772001511760466
# Updating fitness with value 0.3627392200287515
# Updating fitness with value 0.18018093598175292
# Updating fitness with value 0.16076660156249822
# 3490 remaining budget and 5 running jobs
# Launching 5 jobs with new suggestions
# Updating fitness with value 0.17642635019703864
# Updating fitness with value 0.1970139006140457
# 3485 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.17206226438967345
# Updating fitness with value 0.16753680182789504
# 3483 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.17201271357366033
# Updating fitness with value 0.16856123554970875
# Updating fitness with value 0.16745640938407563
# Updating fitness with value 0.1607666015624985
# 3481 remaining budget and 6 running jobs
# Launching 4 jobs with new suggestions
# Updating fitness with value 0.16665728202358832
# Updating fitness with value 0.16610599498409845
# Updating fitness with value 0.17473179208964357
# 3477 remaining budget and 7 running jobs
# Launching 3 jobs with new suggestions
# Updating fitness with value 0.17015536245445023
# Updating fitness with value 0.18354179126838982
# 3474 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.18186512753076145
# 3472 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.17923280329949348
# 3471 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.26205333097800254
# Updating fitness with value 0.19313821136155218
# 3470 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.16076660156249792
# 3468 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.16076660156249856
# 3467 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.1863607001011028
# Updating fitness with value 0.18304412963637656
# Updating fitness with value 0.16850600617274464
# 3466 remaining budget and 7 running jobs
# Launching 3 jobs with new suggestions
# Updating fitness with value 0.16076660156249883
# Updating fitness with value 0.22498116926976386
# 3463 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.19547240570677699
# 3461 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.17254423860487017
# 3460 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.16076660156249842
# Updating fitness with value 0.17163860785897017
# 3459 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.17624750902330127
# 3457 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.16076660156249836
# Updating fitness with value 0.17228075944305354
# Updating fitness with value 0.16076660156249875
# 3456 remaining budget and 7 running jobs
# Launching 3 jobs with new suggestions
# Updating fitness with value 0.16076660156249864
# 3453 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.1607666015624988
# Updating fitness with value 0.16076660156249878
# 3452 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.20138754662970715
# 3450 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.21292078085030616
# Updating fitness with value 0.16076660156249856
# 3449 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.17942315053590469
# Updating fitness with value 0.191279275660041
# Updating fitness with value 0.18874273777739892
# 3447 remaining budget and 7 running jobs
# Launching 3 jobs with new suggestions
# Updating fitness with value 0.16076660156249845
# 3444 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.1626976150630587
# 3443 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.21220159635397795
# Updating fitness with value 0.1994426520568146
# 3442 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.18040990387769115
# 3440 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.1607666015624991
# 3439 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.1966747262843096
# Updating fitness with value 0.1789424789544338
# ...
# Updating fitness with value 0.1607666015624987
# Updating fitness with value 0.16076660156249872
# Updating fitness with value 0.160766601562499
# Updating fitness with value 0.16076660156249908
# 183 remaining budget and 4 running jobs
# Launching 6 jobs with new suggestions
# Updating fitness with value 0.16076660156249795
# 177 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.16076660156249875
# 176 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.1607666015624985
# 175 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.160766601562499
# Updating fitness with value 0.16076660156249828
# Updating fitness with value 0.16076660156249833
# Updating fitness with value 0.16076660156249883
# 174 remaining budget and 6 running jobs
# Launching 4 jobs with new suggestions
# Updating fitness with value 0.16076660156249817
# Updating fitness with value 0.16076660156249795
# Updating fitness with value 0.16076660156249883
# Updating fitness with value 0.16076660156249842
# 170 remaining budget and 6 running jobs
# Launching 4 jobs with new suggestions
# Updating fitness with value 0.16076660156249878
# 166 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.16076660156249895
# 165 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.16076660156249858
# Updating fitness with value 0.16076660156249814
# Updating fitness with value 0.1609236044011526
# 164 remaining budget and 7 running jobs
# Launching 3 jobs with new suggestions
# Updating fitness with value 0.16076660156249833
# Updating fitness with value 0.1607666015624984
# Updating fitness with value 0.16076660156249892
# Updating fitness with value 0.16076660156249875
# Updating fitness with value 0.16076660156249908
# Updating fitness with value 0.160766601562499
# 161 remaining budget and 4 running jobs
# Launching 6 jobs with new suggestions
# Updating fitness with value 0.16076660156249886
# 155 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.16076660156249872
# 154 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.17689970079124334
# Updating fitness with value 0.1607666015624989
# Updating fitness with value 0.16076660156249908
# 153 remaining budget and 7 running jobs
# Launching 3 jobs with new suggestions
# Updating fitness with value 0.1623357624815459
# Updating fitness with value 0.16076660156249875
# Updating fitness with value 0.18356768827653142
# 150 remaining budget and 7 running jobs
# Launching 3 jobs with new suggestions
# Updating fitness with value 0.16076660156249908
# 147 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.1607666015624986
# 146 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.16076660156249864
# 145 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.16627063592678626
# Updating fitness with value 0.16076660156249847
# 144 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.1607666015624987
# Updating fitness with value 0.16076660156249845
# Updating fitness with value 0.16076660156249883
# Updating fitness with value 0.16076660156249817
# Updating fitness with value 0.16076660156249833
# Updating fitness with value 0.16076660156249858
# 142 remaining budget and 4 running jobs
# Launching 6 jobs with new suggestions
# Updating fitness with value 0.16076660156249867
# 136 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.17126932336326578
# 135 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.16076660156249822
# Updating fitness with value 0.17768405185748914
# 134 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.1607666015624987
# Updating fitness with value 0.16076660156249917
# Updating fitness with value 0.16076660156249867
# Updating fitness with value 0.16136910351785308
# 132 remaining budget and 6 running jobs
# Launching 4 jobs with new suggestions
# Updating fitness with value 0.16076660156249872
# 128 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.21027452750993697
# Updating fitness with value 0.16076660156249847
# 127 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.16256652430814278
# 125 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.16681288336269953
# Updating fitness with value 0.18364990316135946
# Updating fitness with value 0.16076660156249828
# Updating fitness with value 0.16076660156249895
# 124 remaining budget and 6 running jobs
# Launching 4 jobs with new suggestions
# Updating fitness with value 0.16076660156249864
# Updating fitness with value 0.16076660156249828
# Updating fitness with value 0.16076660156249842
# Updating fitness with value 0.18570695167275142
# Updating fitness with value 0.17109483862544045
# 120 remaining budget and 5 running jobs
# Launching 5 jobs with new suggestions
# Updating fitness with value 0.160766601562499
# 115 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.19021627164979668
# Updating fitness with value 0.16076660156249847
# 114 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.16076660156249872
# Updating fitness with value 0.16076660156249892
# 112 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.16076660156249806
# 110 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.16076660156249833
# Updating fitness with value 0.16076660156249814
# 109 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.1607666015624983
# 107 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.1607666015624984
# 106 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.17072712883821584
# 105 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.16076660156249822
# 104 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.1607666015624987
# 103 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.16076660156249808
# 102 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.16076660156249883
# 101 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.16076660156249917
# 100 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.16076660156249856
# Updating fitness with value 0.16076660156249897
# Updating fitness with value 0.16577373574800136
# 99 remaining budget and 7 running jobs
# Launching 3 jobs with new suggestions
# Updating fitness with value 0.1608164271641065
# 96 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.17051140441372886
# 95 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.1607666015624986
# Updating fitness with value 0.1648399665333689
# 94 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.1607666015624992
# Updating fitness with value 0.16076660156249883
# Updating fitness with value 0.16076660156249872
# 92 remaining budget and 7 running jobs
# Launching 3 jobs with new suggestions
# Updating fitness with value 0.1607666015624987
# 89 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.16076660156249883
# Updating fitness with value 0.1607666015624985
# Updating fitness with value 0.16518423390650952
# 88 remaining budget and 7 running jobs
# Launching 3 jobs with new suggestions
# Updating fitness with value 0.1607666015624991
# 85 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.16076660156249864
# Updating fitness with value 0.16076660156249817
# Updating fitness with value 0.1607666015624983
# 84 remaining budget and 7 running jobs
# Launching 3 jobs with new suggestions
# Updating fitness with value 0.16076660156249883
# Updating fitness with value 0.16076660156249806
# 81 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.16076660156249847
# 79 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.16076660156249895
# Updating fitness with value 0.16076660156249833
# 78 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.16076660156249867
# 76 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.16911019854553622
# Updating fitness with value 0.1649284381722591
# 75 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.18289446949874755
# Updating fitness with value 0.1607666015624986
# Updating fitness with value 0.16076660156249858
# Updating fitness with value 0.1607666015624989
# Updating fitness with value 0.16682649072381522
# Updating fitness with value 0.1607666015624986
# 73 remaining budget and 4 running jobs
# Launching 6 jobs with new suggestions
# Updating fitness with value 0.16076660156249864
# 67 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.16076660156249822
# 66 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.1607666015624986
# Updating fitness with value 0.1607666015624984
# 65 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.16363203339683507
# Updating fitness with value 0.16076660156249806
# Updating fitness with value 0.1607666015624984
# Updating fitness with value 0.16076660156249833
# Updating fitness with value 0.1607666015624986
# Updating fitness with value 0.16076660156249833
# Updating fitness with value 0.16076660156249878
# 63 remaining budget and 3 running jobs
# Launching 7 jobs with new suggestions
# Updating fitness with value 0.1607666015624982
# 56 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.160766601562498
# 55 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.16076660156249903
# 54 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.16076660156249825
# Updating fitness with value 0.160766601562499
# Updating fitness with value 0.16076660156249906
# Updating fitness with value 0.16076660156249867
# Updating fitness with value 0.1607666015624984
# Updating fitness with value 0.16076660156249864
# 53 remaining budget and 4 running jobs
# Launching 6 jobs with new suggestions
# Updating fitness with value 0.16076660156249878
# 47 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.16724620652903377
# 46 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.1607666015624989
# 45 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.16076660156249817
# Updating fitness with value 0.16076660156249845
# Updating fitness with value 0.16076660156249892
# 44 remaining budget and 7 running jobs
# Launching 3 jobs with new suggestions
# Updating fitness with value 0.16076660156249883
# Updating fitness with value 0.16076660156249878
# Updating fitness with value 0.1847939892687775
# Updating fitness with value 0.19994290554057761
# Updating fitness with value 0.16076660156249895
# 41 remaining budget and 5 running jobs
# Launching 5 jobs with new suggestions
# Updating fitness with value 0.16076660156249908
# 36 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.16076660156249836
# 35 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.16076660156249842
# Updating fitness with value 0.16076660156249864
# Updating fitness with value 0.1607666015624986
# 34 remaining budget and 7 running jobs
# Launching 3 jobs with new suggestions
# Updating fitness with value 0.1607666015624985
# Updating fitness with value 0.16076660156249825
# Updating fitness with value 0.16109867366738742
# Updating fitness with value 0.1607666015624989
# Updating fitness with value 0.16076660156249895
# 31 remaining budget and 5 running jobs
# Launching 5 jobs with new suggestions
# Updating fitness with value 0.1607666015624989
# 26 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.16076660156249878
# 25 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.160766601562499
# Updating fitness with value 0.16076660156249895
# 24 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.17806737317136345
# Updating fitness with value 0.165742591215463
# Updating fitness with value 0.16076660156249867
# Updating fitness with value 0.1689794792377466
# Updating fitness with value 0.16157036802875896
# Updating fitness with value 0.16076660156249853
# 22 remaining budget and 4 running jobs
# Launching 6 jobs with new suggestions
# Updating fitness with value 0.1607666015624989
# 16 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.16076660156249867
# 15 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.16076660156249895
# Updating fitness with value 0.16076660156249836
# 14 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.1607666015624984
# Updating fitness with value 0.1607666015624989
# Updating fitness with value 0.16076660156249858
# 12 remaining budget and 7 running jobs
# Launching 3 jobs with new suggestions
# Updating fitness with value 0.16076660156249867
# Updating fitness with value 0.16076660156249878
# 9 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.16076660156249864
# 7 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.16076660156249922
# 6 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.1607666015624984
# 5 remaining budget and 9 running jobs
# Launching 1 jobs with new suggestions
# Updating fitness with value 0.16076660156249883
# Updating fitness with value 0.16076660156249856
# 4 remaining budget and 8 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.16076660156249858
# Updating fitness with value 0.1607666015624986
# Updating fitness with value 0.1607666015624984
# Updating fitness with value 0.16076660156249856
# Updating fitness with value 0.16076660156249856
# Updating fitness with value 0.16076660156249822
# Updating fitness with value 0.16076660156249833
# 2 remaining budget and 3 running jobs
# Launching 2 jobs with new suggestions
# Updating fitness with value 0.16076660156249875
# 0 remaining budget and 4 running jobs
# Updating fitness with value 0.16076660156249786
# Updating fitness with value 0.1607666015624986
# Updating fitness with value 0.16076660156249886
# 0 remaining budget and 1 running jobs
# Updating fitness with value 0.16076660156249906
# 0 remaining budget and 0 running jobs

# %%
# print(recommendation.value)
xstar = recommendation.value
xstar, blackbox_fidelity(xstar)
# Out:
# (array([ 0.08210458,  0.30051322, -1.84993254, -1.25228267,  2.7900922 ,
#          0.88172711]),
#  0.1607666015624974)

# %%
angle_star = xstar.reshape((3, n))

for q in range(n):
    gate_mat = U3Gate(angle_star[0, n-q-1], angle_star[1, n-q-1], angle_star[2, n-q-1]).to_matrix()
    print("q{:d}\n".format(q), gate_mat) # Measurement Order
# Out:
# q0
#  [[ 0.9887327 +0.j         -0.09517693-0.11553789j]
#  [ 0.0468768 -0.14216265j  0.92162375-0.35805308j]]
# q1
#  [[ 0.99915747+0.j          0.03853141-0.01413062j]
#  [-0.01130777-0.03945223j  0.58916228+0.80697178j]]

# %%
# # Starting Circuit
# r, initial_qc = param_FP_Grover_circuit(noise_params_x0)
# trans_qc_initial = transpile(initial_qc,sim_noise, optimization_level=0)
# state_initial = Statevector.from_instruction(trans_qc_initial)
# counts_initial = state_initial.sample_counts(shots)

# Optimized Circuit
r, opt_qc = param_FP_Grover_circuit(xstar)
trans_qc_opt = transpile(opt_qc,sim_noise, optimization_level=0)
state_opt = Statevector.from_instruction(trans_qc_opt)
counts_opt = state_opt.sample_counts(shots)

plot_histogram([noisy_counts, counts_opt], 
               legend=['Real', 'Optimized'],
               figsize=(max(8,2**(n)),6))
